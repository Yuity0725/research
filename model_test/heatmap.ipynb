# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("all_data.csv", index_col=0)
corr = df.corr()

# %%
corr
# Out:
#             No.1      No.2      No.3      No.4      No.5      No.6      No.7  \
# No.1    1.000000  0.330957  0.325439  0.291557  0.215487  0.450665  0.319405
# No.2    0.330957  1.000000  0.355110  0.391286  0.221874  0.291809  0.299512
# No.3    0.325439  0.355110  1.000000  0.467233  0.194168  0.392349  0.448907
# No.4    0.291557  0.391286  0.467233  1.000000  0.267291  0.364860  0.660212
# No.5    0.215487  0.221874  0.194168  0.267291  1.000000  0.236651  0.215556
# ...          ...       ...       ...       ...       ...       ...       ...
# No.96   0.209792  0.375295  0.156590  0.315871  0.374941  0.276252  0.286717
# No.97   0.287134  0.330033  0.353757  0.375844  0.217297  0.309558  0.349706
# No.98   0.120365  0.074730  0.137249  0.103482  0.268613  0.180481  0.162902
# No.99   0.157082  0.193065  0.244505  0.228336  0.184286  0.202745  0.221968
# No.100  0.210215  0.168656  0.213029  0.290290  0.408741  0.310531  0.373066
#
# ...

# %%
sns.heatmap(corr, square=True)
# Out:
# <Axes: >

# %%
corr.to_csv("corr.csv")

# %%
mean = (corr.abs().sum()-1)/99

# %%
mean.describe()
# Out:
# count    100.000000
# mean       0.356773
# std        0.055766
# min        0.214498
# 25%        0.316701
# 50%        0.368116
# 75%        0.393676
# max        0.449836
# dtype: float64

# %%
mean.to_csv("mean.csv")

# %%
corr.describe()
# Out:
#              No.1        No.2        No.3        No.4        No.5        No.6  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.276352    0.286021    0.290490    0.333626    0.245040    0.321707
# std      0.096142    0.121682    0.121363    0.162979    0.121792    0.096662
# min      0.120365    0.008114    0.013111   -0.082373    0.045100    0.156930
# 25%      0.231848    0.218668    0.217640    0.245297    0.184913    0.264723
# 50%      0.265329    0.288885    0.302605    0.329589    0.227501    0.318672
# 75%      0.302228    0.340794    0.352379    0.434701    0.284394    0.365146
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              No.7        No.8        No.9       No.10  ...       No.91  \
# count  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# mean     0.378246    0.319488    0.367996    0.389750  ...    0.409758
# ...
