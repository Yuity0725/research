# %%
import itertools
import japanize_matplotlib
import json
import pickle
import random
import statistics

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from pprint import pprint
from sklearn.metrics import mean_absolute_error
from tqdm.auto import tqdm

df_data = pd.read_csv("human0821.csv")
df_gt = pd.read_csv("all_data.csv", index_col=0)
dims = (5, 10, 15)

# 重みの読み込み
matrix_dict_nndsvd = {}
for dim in tqdm(dims):
    matrix_dict_nndsvd[dim] = [
        np.load(f"nmf_w/train/nndsvd/{i}/nmf_50000_w_{dim}_nndsvd.npy") for i in range(1000)
    ]
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
matrix_dict_nndsvd[10][0].shape
# Out:
# (100, 10)

# %%
matrix_stack_10 = np.stack(matrix_dict_nndsvd[10])
mean_10 = np.mean(matrix_stack_10, axis=0)
var_10 = np.var(matrix_stack_10, axis=0)

# %%
pd.DataFrame(mean_10)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.018888  2.304244  0.265271  0.133519  0.952167  0.999577  2.456467
# 1   0.265232  0.004811  0.059092  1.294835  0.307810  0.935861  4.140939
# 2   0.000309  0.000000  0.048647  0.004930  0.911229  0.046715  3.458507
# 3   0.716516  0.000000  0.000000  0.245538  3.791612  0.011948  1.839750
# 4   0.000000  1.419350  5.568381  0.217582  0.971307  0.011176  1.989606
# 5   0.148823  0.096458  0.096460  0.119094  1.123395  0.863747  2.417071
# 6   1.433519  0.000000  0.000000  0.000161  3.951482  0.026416  0.271112
# 7   0.000825  0.834018  0.744719  0.112362  3.177079  2.002511  0.721402
# 8   0.024863  0.376258  0.362719  0.196971  4.722785  1.018894  0.629232
# 9   1.120230  0.457277  0.312004  0.393207  3.890630  0.028907  0.498132
# 10  0.024096  4.304082  0.000000  0.945017  1.618330  0.598869  1.049321
# 11  0.734946  0.017575  0.117979  0.906528  3.231732  0.363365  1.101023
# ...

# %%
pd.DataFrame(var_10)
# Out:
#            0             1         2         3         4         5  \
# 0   0.004208  1.659951e-01  0.037944  0.059983  0.167308  0.044254
# 1   0.029927  4.478993e-04  0.019619  0.962485  0.700437  0.160314
# 2   0.000095  0.000000e+00  0.009721  0.024285  0.611154  0.016850
# 3   0.128572  0.000000e+00  0.000000  0.160056  0.646299  0.010112
# 4   0.000000  1.665534e-01  0.184792  0.418523  0.036029  0.008493
# 5   0.007142  1.667738e-01  0.032290  0.079330  0.245543  0.036894
# 6   0.042730  0.000000e+00  0.000000  0.000026  0.107340  0.049202
# 7   0.000317  7.116353e-02  0.012884  0.044507  0.359502  0.109640
# 8   0.004832  5.513175e-02  0.016403  0.151633  0.448837  0.269634
# 9   0.067416  4.452879e-03  0.003031  0.054118  0.146688  0.058937
# 10  0.003331  1.008704e+00  0.000000  0.176651  0.280709  0.130033
# 11  0.001442  5.426317e-03  0.026585  0.219049  0.101631  0.111447
# 12  0.122903  2.420524e-02  0.000000  0.426069  1.160677  0.569051
# ...

# %%
matrix_stack_15 = np.stack(matrix_dict_nndsvd[15])
mean_15 = np.mean(matrix_stack_15, axis=0)
var_15 = np.var(matrix_stack_15, axis=0)
